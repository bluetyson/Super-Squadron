# %%
import pandas as pd
import numpy as np
import random
import time
import datetime
import copy
import json
import math

# %%
df = pd.read_csv('powers.csv')

# %%
powers_set = set(list(df['Mutant'].unique()) + list(df['Self Developed'].unique())  + list(df['Supernatural'].unique())\
                 + list(df['Designed or Sponsored'].unique()) + list(df['Alien'].unique())+ list(df['Accidental/Scientific'].unique())\
                 + list(df['Mutant Secondary'].unique()) + list(df['Self Developed Secondary'].unique())\
                 + list(df['Designed or Sponsored Secondary'].unique()) + list(df['Alien Secondary'].unique())\
                 + list(df['Accidental/Scientific Secondary'].unique())
                )

# %%
print(len(powers_set))
powers_set
# Out:
# 77
# {'Adaption',
#  'Air Generation',
#  'Animal Affinity',
#  'Armour',
#  'Astral Projection',
#  'Body Augmentation',
#  'Cybernetics',
#  'Darkness Generation',
#  'Death Touch',
#  'Defect',
#  'Density Control',
#  'Dimensional Gate',
#  'Disintegration Beam',
#  'Ego Change',
#  'Elasticity',
#  'Emotion Control',
#  'Energy Absorption',
#  'Enhanced Agility',
#  'Enhanced Charisma',
#  'Enhanced Intelligence',
#  'Enhanced Stamina',
#  'Enhanced Strength',
#  'Environment Control',
#  'Fast Recovery',
#  'Flame Generation',
#  'Flight',
#  'Force Beam',
#  'Force Field',
#  'Gimmick',
#  'Gravity Control',
#  'Heightened Attack',
#  'Heightened Defense',
#  'Heightened Expertise',
#  'Heightened Senses',
#  'Heightened Speed',
#  'Ice Generation',
#  'Ice Gneration',
#  'Immateriality',
#  'Immortality',
#  'Inherent Power',
#  'Invisibility',
#  'Invulnerability',
#  'Light Control',
#  'Lightning/Electrical Control',
#  'Magic Device',
#  'Magic Spells',
#  'Magnetic Manipulation',
#  'Metamorphosis',
#  'Mimic',
#  'Mind Control',
#  'Mind Power',
#  'Multiplex',
#  'Mutation',
#  'Non-Requirement of Air',
#  'Organic Powers',
#  'Out of Phase Detection',
#  'Paralysis Ray',
#  'Pet or Companion',
#  'Phantasmal Forces',
#  'Regeneration',
#  'Revivication',
#  'Robotic Body',
#  'Roll again twice',
#  'Self Discipline',
#  'Shape Shift',
#  'Size Change',
#  'Sonic Abilities',
#  'Special Vehicle',
#  'Special Vehjcle',
#  'Special Weapon',
#  'Teleportation',
#  'Temperature Control',
#  'Terra Generation',
#  'Time Travel',
#  'Water Breathing',
#  'Weakness Detection',
#  'Weather Control'}

# %%
powers = pd.DataFrame()

powers['Power'] = sorted(powers_set)
powers['APCost'] = 0
powers['MaxAP'] = 0
powers['AreaEffect'] = 'NA'
powers['DeviceAP'] = 0
powers['DamageAP'] = 0
powers['Duration'] = 0
powers['DurationUnit'] = 'NA'
powers['Range'] = 'NA'
powers['DeviceRange'] = 'NA'

powers
# Out:
#                  Power  APCost  MaxAP AreaEffect  DeviceAP  DamageAP  \
# 0             Adaption       0      0         NA         0         0
# 1       Air Generation       0      0         NA         0         0
# 2      Animal Affinity       0      0         NA         0         0
# 3               Armour       0      0         NA         0         0
# 4    Astral Projection       0      0         NA         0         0
# ..                 ...     ...    ...        ...       ...       ...
# 72    Terra Generation       0      0         NA         0         0
# 73         Time Travel       0      0         NA         0         0
# 74     Water Breathing       0      0         NA         0         0
# 75  Weakness Detection       0      0         NA         0         0
# 76     Weather Control       0      0         NA         0         0
#
#     Duration DurationUnit Range DeviceRange
# 0          0           NA    NA          NA
# 1          0           NA    NA          NA
# 2          0           NA    NA          NA
# 3          0           NA    NA          NA
# 4          0           NA    NA          NA
# ..       ...          ...   ...         ...
# 72         0           NA    NA          NA
# 73         0           NA    NA          NA
# 74         0           NA    NA          NA
# 75         0           NA    NA          NA
# 76         0           NA    NA          NA
#
# [77 rows x 10 columns]

# %%
powers.to_csv('power_details.csv')

# %%
#https://stackoverflow.com/questions/42213338/how-to-create-a-dictionary-from-a-list-of-class-instances-using-one-of-the-attr

# %%
from super_squadron import powers as pw
pw.printtest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2348/3531786790.py in <module>
# ----> 1 from super_squadron import powers as pw
#       2 pw.printtest
#
# ImportError: cannot import name 'powers' from 'super_squadron' (J:\Super-Squadron\super_squadron\super_squadron.py)

# %%
printtest()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2348/2148691902.py in <module>
# ----> 1 printtest()
#
# NameError: name 'printtest' is not defined
